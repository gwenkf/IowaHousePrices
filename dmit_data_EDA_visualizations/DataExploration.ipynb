# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

house_train = pd.read_csv('Dmi_train_20171102.csv')

# %%
house_train['SalePrice'].describe()
sns.distplot(house_train['SalePrice'])
print(house_train['SalePrice'].skew())
print(house_train['SalePrice'].kurt())
# Out:
# 1.88287575977
# 6.53628186006

# %% [markdown]
# Lot Area v SalePrice

# %%
house_train['LotArea'].describe()
var = 'LotArea'
data = pd.concat([house_train['SalePrice'], house_train[var]], axis=1)
#data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000)) ##plot
#definitely seem to have a linear relationship. very steep slope

# %% [markdown]
# Overall Quality Histogram and Boxplot v saleprice

# %%
plt.hist(house_train['OverallQual'])
# Out:
# (array([   2.,    3.,   20.,  116.,  397.,  374.,  319.,  168.,   43.,   18.]),
#  array([  1. ,   1.9,   2.8,   3.7,   4.6,   5.5,   6.4,   7.3,   8.2,
#           9.1,  10. ]),
#  <a list of 10 Patch objects>)

# %%
var = 'OverallQual'
data = pd.concat([house_train['SalePrice'], house_train[var]], axis=1)
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000)
#sale price steadily increasing with quality
# Out:
# (-0.5, 9.5, 0, 800000)

# %% [markdown]
# Overall Condition histogram and boxplot v saleprice

# %%
plt.hist(house_train['OverallCond'])#gap between 4 and 5?
# Out:
# (array([   1.,    5.,   25.,   57.,    0.,  821.,  252.,  205.,   72.,   22.]),
#  array([ 1. ,  1.8,  2.6,  3.4,  4.2,  5. ,  5.8,  6.6,  7.4,  8.2,  9. ]),
#  <a list of 10 Patch objects>)

# %%
var = 'OverallCond'
data = pd.concat([house_train['SalePrice'], house_train[var]], axis=1)
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000)
#similar relationship to above but strangely high salesprices at overallcond = 5
#overallqual seems to have a stronger relationship to saleprice
# Out:
# (-0.5, 8.5, 0, 800000)

# %% [markdown]
# TotalBsmtSF Scatterplot v saleprice

# %%
house_train['TotalBsmtSF'].describe() #assuming 0 means no basement
var = 'TotalBsmtSF'
data = pd.concat([house_train['SalePrice'], house_train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000))
#seem to have linear relationship

# %% [markdown]
# FullBath histogram and boxplot v saleprice **old variable.. pre-dummy creation!

# %%
plt.hist(house_train['FullBath'])
# Out:
# (array([   9.,    0.,    0.,  650.,    0.,    0.,  768.,    0.,    0.,   33.]),
#  array([ 0. ,  0.3,  0.6,  0.9,  1.2,  1.5,  1.8,  2.1,  2.4,  2.7,  3. ]),
#  <a list of 10 Patch objects>)

# %%
var = 'FullBath'
data = pd.concat([house_train['SalePrice'], house_train[var]], axis=1)
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000)
#plot seems to show a relationship but most observations are between 1 and 2
#0 has 9 observations and 3 has 33 - unsure about this one
# Out:
# (-0.5, 3.5, 0, 800000)

# %% [markdown]
# TotRmsAbvGrd histogram and boxplot v saleprice

# %%
plt.hist(house_train['TotRmsAbvGrd'])
# Out:
# (array([  18.,   97.,  275.,  402.,  329.,  262.,   47.,   18.,   11.,    1.]),
#  array([  2. ,   3.2,   4.4,   5.6,   6.8,   8. ,   9.2,  10.4,  11.6,
#          12.8,  14. ]),
#  <a list of 10 Patch objects>)

# %%
var = 'TotRmsAbvGrd'
data = pd.concat([house_train['SalePrice'], house_train[var]], axis=1)
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000)
#seems to be linear relationship
# Out:
# (-0.5, 11.5, 0, 800000)

# %% [markdown]
# YearBuilt scatterplot v saleprice

# %%
var = 'YearBuilt'
data = pd.concat([house_train['SalePrice'], house_train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000))
#houses built more recently seem to be going for higher prices

# %% [markdown]
# GrLivArea scatterplot v saleprice

# %%
house_train['GrLivArea'].describe()
var = 'GrLivArea'
data = pd.concat([house_train['SalePrice'], house_train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000))
#definitely linear relationship

# %% [markdown]
# ExterCond barchart and boxplot v saleprice

# %%
sns.countplot(house_train['ExterCond'])

# %%
var = 'ExterCond'
data = pd.concat([house_train['SalePrice'], house_train[var]], axis=1)
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000)
#doesn't seem to have a compelling relationship. most observations are TA (typical/average)
# Out:
# (-0.5, 4.5, 0, 800000)

# %% [markdown]
# Foundation barchart and boxplot v saleprice

# %%
sns.countplot(house_train['Foundation'])

# %%
var = 'Foundation'
data = pd.concat([house_train['SalePrice'], house_train[var]], axis=1)
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000)
#not a compelling relationship
# Out:
# (-0.5, 5.5, 0, 800000)

# %% [markdown]
# BsmtQual barchart and boxplot v saleprice

# %%
sns.countplot(house_train['BsmtQual'])

# %%
var = 'BsmtQual'
data = pd.concat([house_train['SalePrice'], house_train[var]], axis=1)
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000)
#most observations are Gd and TA
#seems like sale price is increasing with better bsmt quality
# Out:
# (-0.5, 3.5, 0, 800000)

# %% [markdown]
# Fence barchart and boxplot v saleprice

# %%
sns.countplot(house_train['Fence'])

# %%
var = 'Fence'
data = pd.concat([house_train['SalePrice'], house_train[var]], axis=1)
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000)
#not a compelling relationship
# Out:
# (-0.5, 3.5, 0, 800000)

# %% [markdown]
# Neighborhood histogram and boxplot v saleprice

# %%
sns.countplot(house_train['Neighborhood'])

# %%
var = 'Neighborhood'
data = pd.concat([house_train['SalePrice'], house_train[var]], axis=1)
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000)
#not sure this would be the best way to assess relationship between location and price
# Out:
# (-0.5, 24.5, 0, 800000)

# %% [markdown]
# BldgType barchart and boxplot v saleprice

# %%
sns.countplot(house_train['BldgType'])

# %%
var = 'BldgType'
data = pd.concat([house_train['SalePrice'], house_train[var]], axis=1)
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000)
# Out:
# (-0.5, 4.5, 0, 800000)

# %% [markdown]
# KitchenQual barchart and boxplot v saleprice

# %%
sns.countplot(house_train['KitchenQual'])

# %%
var = 'KitchenQual'
data = pd.concat([house_train['SalePrice'], house_train[var]], axis=1)
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000)
#most obs between Gd and TA but price does seem to increase with better quality kitchen - unsure
# Out:
# (-0.5, 3.5, 0, 800000)

# %% [markdown]
# Fireplaces barchart and boxplot v saleprice

# %%
plt.hist(house_train['Fireplaces'])
# Out:
# (array([ 690.,    0.,    0.,  650.,    0.,    0.,  115.,    0.,    0.,    5.]),
#  array([ 0. ,  0.3,  0.6,  0.9,  1.2,  1.5,  1.8,  2.1,  2.4,  2.7,  3. ]),
#  <a list of 10 Patch objects>)

# %%
var = 'Fireplaces'
data = pd.concat([house_train['SalePrice'], house_train[var]], axis=1)
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000)
#not sure how informative this is
# Out:
# (-0.5, 3.5, 0, 800000)

# %% [markdown]
# YearRemodAdd boxplot v saleprice

# %%
var = 'YearRemodAdd'
data = pd.concat([house_train['SalePrice'], house_train[var]], axis=1)
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000)
#could be a relationship but need to figure out how many of these are actual remodel dates v original construction date if 
#never been remodeled
# Out:
# (-0.5, 60.5, 0, 800000)

# %% [markdown]
# Correlation table - Numeric variables

# %%
corrDim = house_train[['SalePrice','LotArea','MasVnrArea','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','LowQualFinSF','GrLivArea','WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch','YearBuilt','YearRemodAdd','gar_type', 'driveway']].corr()
corrDim
# Out:
#                SalePrice   LotArea  MasVnrArea  BsmtUnfSF  TotalBsmtSF  \
# SalePrice       1.000000  0.263843    0.477493   0.214479     0.613581
# LotArea         0.263843  1.000000    0.104160  -0.002618     0.260833
# MasVnrArea      0.477493  0.104160    1.000000   0.114442     0.363936
# BsmtUnfSF       0.214479 -0.002618    0.114442   1.000000     0.415360
# TotalBsmtSF     0.613581  0.260833    0.363936   0.415360     1.000000
# 1stFlrSF        0.605852  0.299475    0.344501   0.317987     0.819530
# 2ndFlrSF        0.319334  0.050986    0.174561   0.004469    -0.174512
# LowQualFinSF   -0.025606  0.004779   -0.069071   0.028167    -0.033245
# GrLivArea       0.708624  0.263116    0.390857   0.240257     0.454868
# WoodDeckSF      0.324413  0.171698    0.159718  -0.005316     0.232019
# OpenPorchSF     0.315856  0.084774    0.125703   0.129005     0.247264
# EnclosedPorch  -0.128578 -0.018340   -0.110204  -0.002538    -0.095478
# ...

# %% [markdown]
# MSSubClass boxplot v saleprice

# %%
var = 'MSSubClass'
data = pd.concat([house_train['SalePrice'], house_train[var]], axis=1)
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000)
# Out:
# (-0.5, 14.5, 0, 800000)

# %% [markdown]
# OpenPorchSF histogram and inspection of 0 values

# %%
house_train[['OpenPorchSF']].hist(bins=70)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000212AD9C3F28>]], dtype=object)

# %%
house_train.loc[house_train.OpenPorchSF == 0]
##656 0 values for OpenPorchSF
656/1460 #45% 0 
house_train['SalePrice'].corr(house_train['OpenPorchSF'])
# Out:
# 0.31585622711605521

# %% [markdown]
# 3SsnPorch histogram

# %% [markdown]
# ScreenPorch histogram and inspection of 0 values

# %%
house_train[['ScreenPorch']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000212AEE46588>]], dtype=object)

# %%
house_train.loc[house_train.ScreenPorch == 0]
#1344 rows with 0 for this variable
1344/1460 #92% 0
house_train['SalePrice'].corr(house_train['ScreenPorch']) #correlation w SalePrice .11
# Out:
# 0.11144657114291115

# %% [markdown]
# Renaming 3SsnPorch column and inspecting 0 values

# %%
house_train = house_train.rename(columns={'3SsnPorch':'ThreeSsnPorch'})

# %%
house_train[['ThreeSsnPorch']].hist(bins = 70)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000212AF318B70>]], dtype=object)

# %%
house_train.loc[house_train.ThreeSsnPorch == 0] #1436 0 values for this variable
1436/1460 #98% 0 values
# Out:
# 0.9835616438356164

# %% [markdown]
# MiscVal histogram and inspection of 0 values

# %%
house_train[['MiscVal']].hist()
house_train.loc[house_train.MiscVal == 0]
1408/1460 #96% 0 values
# Out:
# 0.9643835616438357

# %% [markdown]
# gar_type histogram and inspection of 0 values and correlations

# %%
house_train[['gar_type']].hist()
house_train['SalePrice'].corr(house_train['gar_type']) ##corr with saleprice is .4229
#house_train.loc[house_train.gar_type == 0] #81 0 values 
#81/1460 #5% 0
# Out:
# 0.42290206654236467

# %% [markdown]
# gar_finish histogram and inspection of 0 values and correlations

# %%
house_train[['gar_finish']].hist()
house_train.loc[house_train.gar_finish == 0] #81 values 0
#5% 0 values
house_train['SalePrice'].corr(house_train['gar_finish'])
# Out:
# 0.5492467563332124

# %% [markdown]
# Correlation between BedroomAbvGr and TotRmsAbvGrd

# %%
house_train['BedroomAbvGr'].corr(house_train['TotRmsAbvGrd'])
# Out:
# 0.67661993574264956

# %% [markdown]
# bsmt_height histogram

# %%
house_train[['bsmt_height']].hist()
# Out:
# 0.62292472605884153

# %% [markdown]
# Adding additional numeric variables to correlation table

# %%
corrDim = house_train[['SalePrice','LotArea','MasVnrArea','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','LowQualFinSF','GrLivArea','WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch','YearBuilt','YearRemodAdd','gar_type', 'driveway', 'bsmt_height','exterior_quality', 'home_funct', 'bsmt_exposure', 'MasVnrArea', 'BsmtFinishedShare']].corr()
#corrDim

# %% [markdown]
# gar_perception histogram

# %%
house_train[['gar_perception']].hist()
house_train.loc[house_train.gar_perception == 6] #1372 values are 6
1372/1460 #93% of values are 6
# Out:
# 0.9397260273972603

# %% [markdown]
# exterior_quality histogram

# %%
house_train[['exterior_quality']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000212AF26FBE0>]], dtype=object)

# %% [markdown]
# home_funct histogram

# %%
house_train[['home_funct']].hist()
house_train.loc[house_train.home_funct == 7] #1360 values are 7
1360/1460 #93% values are 7
# Out:
# 0.9315068493150684

# %% [markdown]
# bsmt_exposure histogram and inspection of 0 values

# %%
house_train[['bsmt_exposure']].hist() #do zeros mean no basement?
house_train.loc[house_train.bsmt_exposure == 0] #991 zero values
991/1460 #68% 0 values
# Out:
# 0.6787671232876712

# %% [markdown]
# MasVnrArea histogram and inspection of 0 values

# %%
house_train[['MasVnrArea']].hist()
house_train.loc[house_train.MasVnrArea == 0] #861 0 values
861/1460 #59% values are 0
# Out:
# 0.5897260273972603

# %% [markdown]
# LowQualFinSF histogram and inspection of 0 values

# %%
house_train[['LowQualFinSF']].hist()
house_train.loc[house_train.LowQualFinSF == 0] #1434 0 values
1434/1460 #98% are 0
# Out:
# 0.9821917808219178

# %% [markdown]
# BsmtFinishedShare histogram and inspection of 0 values

# %%
house_train[['BsmtFinishedShare']].hist()
house_train.loc[house_train.BsmtFinishedShare == 0] #467 values are 0
467/1460 #32% values 0
# Out:
# 0.3198630136986301

# %% [markdown]
# LotArea histogram and inspection of 0 values

# %%
house_train[['LotArea']].hist()
#house_train.loc[house_train.LotArea ==0] #no zero values in table??
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000026ABB4A1940>]], dtype=object)
