# %%
import pandas as pd

df = pd.read_csv('Dmi_train_20171102.csv')
df.describe()
# Out:
#         Unnamed: 0           Id   MSSubClass  LotFrontage        LotArea  \
# count  1460.000000  1460.000000  1460.000000  1201.000000    1460.000000
# mean    729.500000   730.500000    56.897260    70.049958   10516.828082
# std     421.610009   421.610009    42.300571    24.284752    9981.264932
# min       0.000000     1.000000    20.000000    21.000000    1300.000000
# 25%     364.750000   365.750000    20.000000    59.000000    7553.500000
# 50%     729.500000   730.500000    50.000000    69.000000    9478.500000
# 75%    1094.250000  1095.250000    70.000000    80.000000   11601.500000
# max    1459.000000  1460.000000   190.000000   313.000000  215245.000000
#
#        OverallQual  OverallCond    YearBuilt  YearRemodAdd   MasVnrArea  \
# count  1460.000000  1460.000000  1460.000000   1460.000000  1452.000000
# mean      6.099315     5.575342  1971.267808   1984.865753   103.685262
# std       1.382997     1.112799    30.202904     20.645407   181.066207
# ...

# %%
df.MSZoning.value_counts()
# Out:
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %% [markdown]
# I think commercial zoning is important...

# %%
plt.violinplot([df[df.MSZoning == x].SalePrice for x in set(df.MSZoning)])
print(set(df.MSZoning))
# Out:
# {'FV', 'C (all)', 'RL', 'RH', 'RM'}

# %%
import numpy as np
data = [np.random.normal(0, std, size=100) for std in [1,2,3]]
data
# Out:
# [array([ 0.68966386,  1.40326188, -2.74208645, -1.50853454,  1.73068756,
#         -0.56607188, -0.55348772,  2.68224864, -1.16444893,  0.80232758,
#         -0.92461675,  1.34740474, -0.67793579, -0.50488388, -2.89382772,
#          0.42570773,  0.20229605,  1.20623663, -0.61802125, -0.9812075 ,
#          1.49496025,  1.30653021, -0.07245082, -1.17717661, -0.50022058,
#         -0.29942729,  0.94373178,  0.18852073,  1.33822884, -0.97846722,
#          0.50220109, -0.25295264,  1.92472408,  0.86061727,  1.35067844,
#          0.99340006,  0.62566777, -1.46299919,  0.69828241,  1.06654822,
#          0.10693001, -0.36803492, -0.16478181, -0.34050281, -1.43148805,
#         -0.06254909, -0.16025559,  0.6049185 ,  0.11207444, -1.34110545,
#          0.44608592,  1.14683389,  1.19020225,  1.31574274,  0.8059411 ,
#         -0.71406004, -1.11935808,  1.99444372, -0.35570849, -1.99236479,
#         -0.17718416,  1.20643294,  1.80052475,  0.72190402,  1.22453734,
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.violinplot(x = df.MSZoning, y = df.SalePrice)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-6c7810289edd> in <module>()
#       2 get_ipython().magic('matplotlib inline')
#       3
# ----> 4 plt.violinplot(x = df.MSZoning, y = df.SalePrice)
#
# TypeError: violinplot() got an unexpected keyword argument 'x'
